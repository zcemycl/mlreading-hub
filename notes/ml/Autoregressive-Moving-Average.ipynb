# %%
import math
import pandas as pd
import matplotlib.pyplot as plt
from pandas_datareader.data import DataReader
from datetime import datetime as dt

# %%
selected_stocks = ['AAPL','MSFT','AMZN','GOOGL',
                    'TSLA','NVDA','KO','WMT','DIS','LIN']

# %%
goog = DataReader(selected_stocks,  "yahoo", dt(2017,1,1), dt(2022,1,1))

# %%
goog.columns
# Out:
# MultiIndex([('Adj Close',  'AAPL'),
#             ('Adj Close',  'MSFT'),
#             ('Adj Close',  'AMZN'),
#             ('Adj Close', 'GOOGL'),
#             ('Adj Close',  'TSLA'),
#             ('Adj Close',  'NVDA'),
#             ('Adj Close',    'KO'),
#             ('Adj Close',   'WMT'),
#             ('Adj Close',   'DIS'),
#             ('Adj Close',   'LIN'),
#             (    'Close',  'AAPL'),
#             (    'Close',  'MSFT'),
#             (    'Close',  'AMZN'),
#             (    'Close', 'GOOGL'),
#             (    'Close',  'TSLA'),
#             (    'Close',  'NVDA'),
#             (    'Close',    'KO'),
#             (    'Close',   'WMT'),
#             (    'Close',   'DIS'),
#             (    'Close',   'LIN'),
#             (     'High',  'AAPL'),
#             (     'High',  'MSFT'),
#             (     'High',  'AMZN'),
#             (     'High', 'GOOGL'),
#             (     'High',  'TSLA'),
#             (     'High',  'NVDA'),
# ...

# %%
goog
# Out:
# Attributes   Adj Close                                                  \
# Symbols           AAPL        MSFT        AMZN       GOOGL        TSLA
# Date
# 2017-01-03   27.174755   57.645378   37.683498   40.400501   14.466000
# 2017-01-04   27.144337   57.387447   37.859001   40.388500   15.132667
# 2017-01-05   27.282379   57.387447   39.022499   40.651001   15.116667
# 2017-01-06   27.586531   57.884869   39.799500   41.260502   15.267333
# 2017-01-09   27.839212   57.700638   39.846001   41.359001   15.418667
# ...                ...         ...         ...         ...         ...
# 2021-12-27  179.289444  339.270996  169.669495  147.906494  364.646667
# 2021-12-28  178.255447  338.082092  170.660995  146.686996  362.823334
# 2021-12-29  178.344925  338.775635  169.201004  146.654999  362.063324
# 2021-12-30  177.171722  336.170044  168.644501  146.200500  356.779999
# 2021-12-31  176.545364  333.197876  166.716995  144.852005  352.260010
#
# ...

# %%
goog['Adj Close']
# Out:
# Symbols           AAPL        MSFT        AMZN       GOOGL        TSLA  \
# Date
# 2017-01-03   27.174755   57.645378   37.683498   40.400501   14.466000
# 2017-01-04   27.144337   57.387447   37.859001   40.388500   15.132667
# 2017-01-05   27.282379   57.387447   39.022499   40.651001   15.116667
# 2017-01-06   27.586531   57.884869   39.799500   41.260502   15.267333
# 2017-01-09   27.839212   57.700638   39.846001   41.359001   15.418667
# ...                ...         ...         ...         ...         ...
# 2021-12-27  179.289444  339.270996  169.669495  147.906494  364.646667
# 2021-12-28  178.255447  338.082092  170.660995  146.686996  362.823334
# 2021-12-29  178.344925  338.775635  169.201004  146.654999  362.063324
# 2021-12-30  177.171722  336.170044  168.644501  146.200500  356.779999
# 2021-12-31  176.545364  333.197876  166.716995  144.852005  352.260010
#
# Symbols           NVDA         KO         WMT         DIS         LIN
# Date
# ...
